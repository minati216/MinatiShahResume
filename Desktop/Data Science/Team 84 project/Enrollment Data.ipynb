# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
e_data = pd.read_csv('ELSI_California_Ethnicity.csv')
print(e_data.columns)
print(e_data.info)
# Out:
# Index(['ELSI Export', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22'],
#       dtype='object')
# <bound method DataFrame.info of                                             ELSI Export Unnamed: 1 Unnamed: 2  \
# 0                                                   NaN        NaN        NaN
# 1     National Center for Education Statistics - htt...        NaN        NaN
# 2                                                   NaN        NaN        NaN
# 3     This is a District based table with the follow...        NaN        NaN
# 4                                                   NaN        NaN        NaN
# ...

# %% [markdown]
# ### Print DataFrame

# %%
e_data.head()
# Out:
#                                          ELSI Export Unnamed: 1 Unnamed: 2  \
# 0                                                NaN        NaN        NaN
# 1  National Center for Education Statistics - htt...        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3  This is a District based table with the follow...        NaN        NaN
# 4                                                NaN        NaN        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9  ... Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17  \
# ...

# %% [markdown]
# ### Remove 'NaN' rows

# %%
clean_data = e_data.dropna(how = 'all')
print(clean_data.info)
clean_data.head()
# Out:
# <bound method DataFrame.info of                                             ELSI Export  \
# 1     National Center for Education Statistics - htt...
# 3     This is a District based table with the follow...
# 5                                           Agency Name
# 6                                           ABC UNIFIED
# 7                                   ACALANES UNION HIGH
# ...                                                 ...
# 1166                     YUCAIPA-CALIMESA JOINT UNIFIED
# 1169  Data Source: U.S. Department of Education Nati...
# 1171      † indicates that the data are not applicable.
# 1172             – indicates that the data are missing.
# 1173  ‡ indicates that the data do not meet NCES dat...
#
#                                        Unnamed: 1  \
# 1                                             NaN
# 3                                             NaN
# 5     State Name [District] Latest available year
# 6                                      California
# ...

# %% [markdown]
# ### Replace 'Nan' values with 0
# Print DataFrame

# %%
#e_data.fillna(0)
#e_data.apply(pd.to_numeric, errors = 'coerce')
clean_data.replace(np.nan, 0, inplace = True)
clean_data.head()
# Out:
# /home/jovyan/.local/lib/python3.6/site-packages/pandas/core/frame.py:4389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
#                                          ELSI Export  \
# 1  National Center for Education Statistics - htt...
# 3  This is a District based table with the follow...
# 5                                        Agency Name
# 6                                        ABC UNIFIED
# 7                                ACALANES UNION HIGH
#
#                                     Unnamed: 1  \
# 1                                            0
# 3                                            0
# 5  State Name [District] Latest available year
# 6                                   California
# 7                                   California
#
# ...
