# %%
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy
import csv

# %%
pwd
# Out:
# '/home/jovyan/work/Desktop/Data Science/Team 84 project'

# %%
variable = pd.read_csv("/home/jovyan/work/Desktop/Data Science/Team 84 project/ELSI_California_district_enrollment_ethnicity_2016_2017-PK_G5.csv")
variable1 = pd.read_csv("/home/jovyan/work/Desktop/Data Science/Team 84 project/ELSI_California_district_enrollment_ethnicity_2016_2017_G10-G12.csv")
variable2 = pd.read_csv("/home/jovyan/work/Desktop/Data Science/Team 84 project/ELSI_csv_California_district_enrollment_ethnicity_2016_2017_G6-9.csv")
assessment = pd.read_csv("/home/jovyan/work/Desktop/Data Science/Team 84 project/assessment_ethnicity 2.csv")
Total_enrollment = pd.read_csv("/home/jovyan/work/Desktop/Data Science/Team 84 project/DS4A_team84-main/notebooks/total_enrollment_per_race_with_districtcode.csv")
Total_enrollment.head()
# Out:
#    Unnamed: 0  District Code               Agency Name   Black  Hispanic  \
# 0           0          64212               ABC UNIFIED  1791.0    9425.0
# 1           1          61630       ACALANES UNION HIGH    95.0     508.0
# 2           2          66761          ACKERMAN CHARTER     4.0      74.0
# 3           3          75309  ACTON-AGUA DULCE UNIFIED   705.0    3466.0
# 4           4          67587       ADELANTO ELEMENTARY  2156.0    6327.0
#
#     White  Asian or Pacific Islander  American Indian/Alaska Native  \
# 0  1302.0                     7459.0                           63.0
# 1  3622.0                      850.0                            9.0
# 2   460.0                        9.0                            2.0
# 3  4199.0                      536.0                           36.0
# 4  1010.0                      139.0                           35.0
#
#    Hawaiian Native/Pacific Islander  Two or More Races  Total Enrollment  \
# ...

# %%
assessment.head()
assessment['Total Standard Exceeeded'] =assessment['Students Tested']*assessment['Percentage Standard Exceeded']
assessment.head()
# Out:
#    County Code  District Code  Subgroup ID  Grade  Test Id  \
# 0            1          10017           74     11        2
# 1            1          10017           74     11        1
# 2            1          10017           78     11        2
# 3            1          10017           78     11        1
# 4            1          31617           78      8        2
#
#    CAASPP Reported Enrollment  Students Tested  Mean Scale Score  \
# 0                        72.0             22.0            2403.7
# 1                        72.0             20.0            2419.6
# 2                        51.0             16.0            2431.3
# 3                        51.0             12.0            2464.9
# 4                        13.0             13.0            2375.8
#
#    Percentage Standard Exceeded  Percentage Standard Met  \
# 0                           0.0                     0.00
# 1                           0.0                     0.00
# ...

# %%
assessment.groupby(['District Code']).sum()
# Out:
#                County Code  Subgroup ID  Grade  Test Id  \
# District Code
# 10017                    4          304     44        6
# 10033                   12          320     30        6
# 10041                   32          636     74       12
# 10058                   70         1120     88       21
# 10074                   42          460     60        9
# 10082                   80          796     86       15
# 10090                  162         1428    132       27
# 10108                   80          620     82       12
# 10124                   24          160     22        3
# 10132                   39          234     30        4
# 10140                   28          156     22        3
# 10157                  540         2804    240       54
# 10165                   32          156     22        3
# 10199                  304         1374    146       24
# 10207                  160          628     74       12
# ...
